# %%
import wntr 
# Create a water network model
wn.write_inpfile('filename.inp', version=2.0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_53268/288986602.py in <module>
#       1 import wntr as wn
#       2 # Create a water network model
# ----> 3 wn.write_inpfile('filename.inp', version=2.0)
#
# AttributeError: module 'wntr' has no attribute 'write_inpfile'

# %%
import pandas as pd

# %%
import geopandas as gpd
shapefile = gpd.read_file("D:\Smartterra\Cossepore\DMA1 shape file\DMA 1 GIS SHP files-20220630T060558Z-001\DMA 1 GIS SHP files\Consolidated_network_DMA1.shp")
print(shapefile)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: D:\Smartterra\Cossepore\DMA1 shape file\DMA 1 GIS SHP files-20220630T060558Z-001\DMA 1 GIS SHP files\Consolidated_network_DMA1.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 import geopandas as gpd
# ----> 2 shapefile = gpd.read_file("D:\Smartterra\Cossepore\DMA1 shape file\DMA 1 GIS SHP files-20220630T060558Z-001\DMA 1 GIS SHP files\Consolidated_network_DMA1.shp")
#       3 print(shapefile)
#
# ...

# %%
import geopandas as gpd

# %%
import wntr

# %%
 wn = wntr.network.WaterNetworkModel("C:\Users\Lenovo\Desktop\phd\c code\DMA1_COssepore\DMA1_COssepore\DMA1.inp") 
print(wn)
# Out:
#   Input In [19]
#     wn = wntr.network.WaterNetworkModel("C:\Users\Lenovo\Desktop\phd\c code\DMA1_COssepore\DMA1_COssepore\DMA1.inp")
#                                                                                                                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import csv

# %%
import pandas as pd

data = pd.read_csv (r'D:\Smartterra\Cossepore\DMA1 shape file\DMA1 epanet\DMA1.inp')
df = pd.DataFrame(data, columns= ['Time','PT_01'])
print (df)
# Out:
#           Time  PT_01
# 0  12:00:00 AM  0.062
# 1  12:15:00 AM  0.000
# 2  12:30:00 AM  0.000
# 3  12:45:00 AM  0.000
# 4  01:00:00 AM  0.000
# 5  01:15:00 AM  0.000
# 6  01:30:00 AM  0.000
# 7  01:45:00 AM  0.000
# 8  02:00:00 AM  0.000

# %%
f = open('D:\Smartterra\Cossepore\DMA1 shape file\DMA1 epanet\DMA1.inp', 'r')
print(f.read())
f.close()
# Out:
# [TITLE]
# Scenario: Customer meter
# Date: 17-07-2022 20:34:44
#
# [JUNCTIONS]
# ;ID              	Elev        	Demand      	Pattern
#  30              	5.61        	0.087961408 	1612            	;
#  31              	5.95        	0           	                	;
#  32              	5.33        	0           	                	;
#  33              	4.95        	0.073007994 	1614            	;
#  35              	3.49        	0.448580341 	1614            	;
#  36              	5.35        	0           	                	;
#  37              	5.2         	0           	                	;
#  38              	4.7         	0.094864447 	1614            	;
#  39              	4.01        	0.731602199 	1614            	;
#  40              	5.46        	0.12817049  	1612            	;
#  41              	5.25        	0.171117815 	1614            	;
#  42              	5.04        	0.095542653 	1612            	;
#  43              	4.45        	0.275153806 	1612            	;
# ...

# %%
wn1 = wntr.network.WaterNetworkModel(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 wn1 = wntr.network.WaterNetworkModel(f)
#
# File ~\anaconda3\lib\site-packages\wntr\network\model.py:75, in WaterNetworkModel.__init__(self, inp_file_name)
#      73 self._inpfile = None
#      74 if inp_file_name:
# ---> 75     self.read_inpfile(inp_file_name)
#      77 # To be deleted and/or renamed and/or moved
#      78 # Time parameters
#      79 self.sim_time = 0.0
#
# File ~\anaconda3\lib\site-packages\wntr\network\model.py:1485, in WaterNetworkModel.read_inpfile(self, filename)
#    1475 def read_inpfile(self, filename):
#    1476     """
#    1477     Defines water network model components from an EPANET INP file
#    1478
#    (...)
#    1483
#    1484     """
# -> 1485     return wntr.network.io.read_inpfile(filename, append=self)
#
# ...
